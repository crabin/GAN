# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers

# %% [markdown]
# ## Reading Data

# %%
feature=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count", 
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

# %%
train='DATA/nslkdd/KDDTrain+.txt'
test='DATA/nslkdd/KDDTest+.txt'
test21='DATA/nslkdd/KDDTest-21.txt'
train_data=pd.read_csv(train,names=feature)
test_data=pd.read_csv(test,names=feature)
test_data21 = pd.read_csv(test21, names= feature)
data= pd.concat([train_data, test_data], ignore_index=True)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 148512         0           tcp      smtp   SF        794        333     0
# 148513         0           tcp      http   SF        317        938     0
# 148514         0           tcp      http   SF      54540       8314     0
# 148515         0           udp  domain_u   SF         42         42     0
# 148516         0           tcp    sunrpc  REJ          0          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 148512               0       0    0  ...                    0.72
# 148513               0       0    0  ...                    1.00
# 148514               0       0    2  ...                    1.00
# 148515               0       0    0  ...                    0.99
# 148516               0       0    0  ...                    0.08
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 148512                    0.06                         0.01
# 148513                    0.00                         0.01
# 148514                    0.00                         0.00
# 148515                    0.01                         0.00
# 148516                    0.03                         0.00
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 148512                         0.01                  0.01
# 148513                         0.01                  0.01
# 148514                         0.00                  0.00
# 148515                         0.00                  0.00
# 148516                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 148512                      0.00                  0.00
# 148513                      0.00                  0.00
# 148514                      0.00                  0.07
# 148515                      0.00                  0.00
# 148516                      0.00                  0.44
#
#         dst_host_srv_rerror_rate    label  difficulty
# 0                           0.00   normal          20
# 1                           0.00   normal          15
# 2                           0.00  neptune          19
# 3                           0.01   normal          21
# 4                           0.00   normal          21
# ...                          ...      ...         ...
# 148512                      0.00   normal          21
# 148513                      0.00   normal          21
# 148514                      0.07     back          15
# 148515                      0.00   normal          21
# 148516                      1.00    mscan          14
#
# [148517 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty'],axis=1,inplace=True)

# %% [markdown]
# ## Exploring Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 47.6+ MB

# %%
data.describe().T
# Out:
#                                 count          mean           std  min    25%  \
# duration                     148517.0    276.779305  2.460683e+03  0.0   0.00
# src_bytes                    148517.0  40227.949299  5.409612e+06  0.0   0.00
# dst_bytes                    148517.0  17088.853593  3.703525e+06  0.0   0.00
# land                         148517.0      0.000215  1.467714e-02  0.0   0.00
# wrong_fragment               148517.0      0.020523  2.400691e-01  0.0   0.00
# urgent                       148517.0      0.000202  1.941708e-02  0.0   0.00
# hot                          148517.0      0.189379  2.013160e+00  0.0   0.00
# num_failed_logins            148517.0      0.004323  7.224823e-02  0.0   0.00
# logged_in                    148517.0      0.402789  4.904606e-01  0.0   0.00
# num_compromised              148517.0      0.255062  2.223137e+01  0.0   0.00
# root_shell                   148517.0      0.001508  3.880696e-02  0.0   0.00
# su_attempted                 148517.0      0.000976  4.238907e-02  0.0   0.00
# num_root                     148517.0      0.273726  2.268902e+01  0.0   0.00
# num_file_creations           148517.0      0.012073  5.178631e-01  0.0   0.00
# num_shells                   148517.0      0.000525  2.770051e-02  0.0   0.00
# num_access_files             148517.0      0.004013  9.525663e-02  0.0   0.00
# num_outbound_cmds            148517.0      0.000000  0.000000e+00  0.0   0.00
# is_host_login                148517.0      0.000081  8.988484e-03  0.0   0.00
# is_guest_login               148517.0      0.012308  1.102585e-01  0.0   0.00
# count                        148517.0     83.336561  1.167607e+02  0.0   2.00
# srv_count                    148517.0     28.251937  7.536963e+01  0.0   2.00
# serror_rate                  148517.0      0.256925  4.319178e-01  0.0   0.00
# srv_serror_rate              148517.0      0.255337  4.325783e-01  0.0   0.00
# rerror_rate                  148517.0      0.137947  3.393872e-01  0.0   0.00
# srv_rerror_rate              148517.0      0.138487  3.417829e-01  0.0   0.00
# same_srv_rate                148517.0      0.672983  4.365437e-01  0.0   0.10
# diff_srv_rate                148517.0      0.067761  1.946658e-01  0.0   0.00
# srv_diff_host_rate           148517.0      0.097441  2.588856e-01  0.0   0.00
# dst_host_count               148517.0    183.928042  9.852833e+01  0.0  87.00
# dst_host_srv_count           148517.0    119.462661  1.112323e+02  0.0  11.00
# dst_host_same_srv_rate       148517.0      0.534521  4.480612e-01  0.0   0.05
# dst_host_diff_srv_rate       148517.0      0.084103  1.941020e-01  0.0   0.00
# dst_host_same_src_port_rate  148517.0      0.145932  3.086376e-01  0.0   0.00
# dst_host_srv_diff_host_rate  148517.0      0.030584  1.089751e-01  0.0   0.00
# dst_host_serror_rate         148517.0      0.256122  4.284996e-01  0.0   0.00
# dst_host_srv_serror_rate     148517.0      0.251304  4.297194e-01  0.0   0.00
# dst_host_rerror_rate         148517.0      0.136220  3.227411e-01  0.0   0.00
# dst_host_srv_rerror_rate     148517.0      0.136397  3.352823e-01  0.0   0.00
#
#                                 50%     75%           max
# duration                       0.00    0.00  5.771500e+04
# src_bytes                     44.00  278.00  1.379964e+09
# dst_bytes                      0.00  571.00  1.309937e+09
# land                           0.00    0.00  1.000000e+00
# wrong_fragment                 0.00    0.00  3.000000e+00
# urgent                         0.00    0.00  3.000000e+00
# hot                            0.00    0.00  1.010000e+02
# num_failed_logins              0.00    0.00  5.000000e+00
# logged_in                      0.00    1.00  1.000000e+00
# num_compromised                0.00    0.00  7.479000e+03
# root_shell                     0.00    0.00  1.000000e+00
# su_attempted                   0.00    0.00  2.000000e+00
# num_root                       0.00    0.00  7.468000e+03
# num_file_creations             0.00    0.00  1.000000e+02
# num_shells                     0.00    0.00  5.000000e+00
# num_access_files               0.00    0.00  9.000000e+00
# num_outbound_cmds              0.00    0.00  0.000000e+00
# is_host_login                  0.00    0.00  1.000000e+00
# is_guest_login                 0.00    0.00  1.000000e+00
# count                         13.00  141.00  5.110000e+02
# srv_count                      7.00   17.00  5.110000e+02
# serror_rate                    0.00    0.85  1.000000e+00
# srv_serror_rate                0.00    0.91  1.000000e+00
# rerror_rate                    0.00    0.00  1.000000e+00
# srv_rerror_rate                0.00    0.00  1.000000e+00
# same_srv_rate                  1.00    1.00  1.000000e+00
# diff_srv_rate                  0.00    0.06  1.000000e+00
# srv_diff_host_rate             0.00    0.00  1.000000e+00
# dst_host_count               255.00  255.00  2.550000e+02
# dst_host_srv_count            72.00  255.00  2.550000e+02
# dst_host_same_srv_rate         0.60    1.00  1.000000e+00
# dst_host_diff_srv_rate         0.02    0.07  1.000000e+00
# dst_host_same_src_port_rate    0.00    0.05  1.000000e+00
# dst_host_srv_diff_host_rate    0.00    0.01  1.000000e+00
# dst_host_serror_rate           0.00    0.60  1.000000e+00
# dst_host_srv_serror_rate       0.00    0.50  1.000000e+00
# dst_host_rerror_rate           0.00    0.00  1.000000e+00
# dst_host_srv_rerror_rate       0.00    0.00  1.000000e+00

# %%
# number of attack labels 
data['label'].value_counts()
# Out:
# label
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: count, dtype: int64

# %%
# Redistribute across common attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)      
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# label
# normal    77054
# Dos       53387
# Probe     14077
# R2L        3880
# U2R         119
# Name: count, dtype: int64

# %% [markdown]
# ### Protocol

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
label = pd.DataFrame(data.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = label.apply(le2.fit_transform)
data['intrusion'] = enc_label
print(data.shape)
data
# Out:
# (148517, 43)
#         duration protocol_type   service flag  src_bytes  dst_bytes     land  \
# 0      -0.112481           tcp  ftp_data   SF  -0.007346  -0.004614 -0.01468
# 1      -0.112481           udp     other   SF  -0.007409  -0.004614 -0.01468
# 2      -0.112481           tcp   private   S0  -0.007436  -0.004614 -0.01468
# 3      -0.112481           tcp      http   SF  -0.007394  -0.002413 -0.01468
# 4      -0.112481           tcp      http   SF  -0.007400  -0.004501 -0.01468
# ...          ...           ...       ...  ...        ...        ...      ...
# 148512 -0.112481           tcp      smtp   SF  -0.007290  -0.004524 -0.01468
# 148513 -0.112481           tcp      http   SF  -0.007378  -0.004361 -0.01468
# 148514 -0.112481           tcp      http   SF   0.002646  -0.002369 -0.01468
# 148515 -0.112481           udp  domain_u   SF  -0.007429  -0.004603 -0.01468
# 148516 -0.112481           tcp    sunrpc  REJ  -0.007436  -0.004614 -0.01468
#
#         wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0            -0.085488 -0.010403 -0.094071  ...               -0.813554
# 1            -0.085488 -0.010403 -0.094071  ...               -1.192968
# 2            -0.085488 -0.010403 -0.094071  ...               -0.969783
# 3            -0.085488 -0.010403 -0.094071  ...                1.038878
# 4            -0.085488 -0.010403 -0.094071  ...                1.038878
# ...                ...       ...       ...  ...                     ...
# 148512       -0.085488 -0.010403 -0.094071  ...                0.413961
# 148513       -0.085488 -0.010403 -0.094071  ...                1.038878
# 148514       -0.085488 -0.010403  0.899396  ...                1.038878
# 148515       -0.085488 -0.010403 -0.094071  ...                1.016560
# 148516       -0.085488 -0.010403 -0.094071  ...               -1.014420
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    -0.278736                     0.077981
# 1                     2.657874                     2.378421
# 2                    -0.175697                    -0.472829
# 3                    -0.433294                    -0.375627
# 4                    -0.433294                    -0.472829
# ...                        ...                          ...
# 148512               -0.124178                    -0.440428
# 148513               -0.433294                    -0.440428
# 148514               -0.433294                    -0.472829
# 148515               -0.381775                    -0.472829
# 148516               -0.278736                    -0.472829
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         -0.280650             -0.597720
# 1                         -0.280650             -0.597720
# 2                         -0.280650              1.736012
# 3                          0.086408             -0.527708
# 4                         -0.280650             -0.597720
# ...                             ...                   ...
# 148512                    -0.188885             -0.574382
# 148513                    -0.188885             -0.574382
# 148514                    -0.280650             -0.597720
# 148515                    -0.280650             -0.597720
# 148516                    -0.280650             -0.597720
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      -0.584813             -0.267151
# 1                      -0.584813             -0.422074
# 2                       1.742295             -0.422074
# 3                      -0.561542             -0.422074
# 4                      -0.584813             -0.422074
# ...                          ...                   ...
# 148512                 -0.584813             -0.422074
# 148513                 -0.584813             -0.422074
# 148514                 -0.584813             -0.205182
# 148515                 -0.584813             -0.422074
# 148516                 -0.584813              0.941252
#
#         dst_host_srv_rerror_rate   label  intrusion
# 0                      -0.406815  normal          4
# 1                      -0.406815  normal          4
# 2                      -0.406815     Dos          0
# 3                      -0.376989  normal          4
# 4                      -0.406815  normal          4
# ...                          ...     ...        ...
# 148512                 -0.406815  normal          4
# 148513                 -0.406815  normal          4
# 148514                 -0.198035     Dos          0
# 148515                 -0.406815  normal          4
# 148516                  2.575756   Probe          1
#
# [148517 rows x 43 columns]

# %%
data.drop(labels= ['label'], axis=1, inplace=True)
print(data.shape)
# Out:
# (148517, 42)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")  
print(data.shape)
# Out:
# (148517, 123)

# %%
y_data= data['intrusion']
X_data= data.drop(labels=['intrusion'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (148517, 122)
# y_train has shape: (148517,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (118813, 122)
#  (29704, 122)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
model = Sequential() # initializing model
model.add(LSTM(64,return_sequences=True,input_shape = (1, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Flatten())
model.add(Dense(units=50))
# output layer with softmax activation
model.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 64)             47872
#
#  dropout (Dropout)           (None, 1, 64)             0
#
#  lstm_1 (LSTM)               (None, 1, 64)             33024
#
#  dropout_1 (Dropout)         (None, 1, 64)             0
#
#  lstm_2 (LSTM)               (None, 1, 64)             33024
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 117425 (458.69 KB)
# Trainable params: 117425 (458.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')
history = model.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 9s 156ms/step - loss: 1.5262 - accuracy: 0.6229 - val_loss: 1.3594 - val_accuracy: 0.8257
# Epoch 2/100
# 20/20 [==============================] - 2s 91ms/step - loss: 1.0061 - accuracy: 0.8312 - val_loss: 0.5490 - val_accuracy: 0.8313
# Epoch 3/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.4639 - accuracy: 0.8413 - val_loss: 0.3926 - val_accuracy: 0.8501
# Epoch 4/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.3627 - accuracy: 0.8775 - val_loss: 0.3228 - val_accuracy: 0.9175
# Epoch 5/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.2870 - accuracy: 0.9268 - val_loss: 0.2359 - val_accuracy: 0.9377
# Epoch 6/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.2140 - accuracy: 0.9397 - val_loss: 0.1872 - val_accuracy: 0.9435
# Epoch 7/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1778 - accuracy: 0.9447 - val_loss: 0.1609 - val_accuracy: 0.9474
# Epoch 8/100
# 20/20 [==============================] - 2s 91ms/step - loss: 0.1541 - accuracy: 0.9495 - val_loss: 0.1397 - val_accuracy: 0.9528
# Epoch 9/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1349 - accuracy: 0.9531 - val_loss: 0.1217 - val_accuracy: 0.9548
# Epoch 10/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1171 - accuracy: 0.9574 - val_loss: 0.1060 - val_accuracy: 0.9607
# Epoch 11/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.1034 - accuracy: 0.9623 - val_loss: 0.0938 - val_accuracy: 0.9650
# Epoch 12/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0941 - accuracy: 0.9666 - val_loss: 0.0855 - val_accuracy: 0.9679
# Epoch 13/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0851 - accuracy: 0.9704 - val_loss: 0.0784 - val_accuracy: 0.9743
# Epoch 14/100
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0805 - accuracy: 0.9724 - val_loss: 0.0729 - val_accuracy: 0.9760
# Epoch 15/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0748 - accuracy: 0.9750 - val_loss: 0.0687 - val_accuracy: 0.9769
# Epoch 16/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0712 - accuracy: 0.9757 - val_loss: 0.0656 - val_accuracy: 0.9779
# Epoch 17/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0697 - accuracy: 0.9759 - val_loss: 0.0627 - val_accuracy: 0.9792
# Epoch 18/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0679 - accuracy: 0.9768 - val_loss: 0.0612 - val_accuracy: 0.9811
# Epoch 19/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0655 - accuracy: 0.9777 - val_loss: 0.0592 - val_accuracy: 0.9804
# Epoch 20/100
# 20/20 [==============================] - 2s 103ms/step - loss: 0.0623 - accuracy: 0.9790 - val_loss: 0.0577 - val_accuracy: 0.9807
# Epoch 21/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0595 - accuracy: 0.9801 - val_loss: 0.0554 - val_accuracy: 0.9820
# Epoch 22/100
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0590 - accuracy: 0.9797 - val_loss: 0.0544 - val_accuracy: 0.9830
# Epoch 23/100
# 20/20 [==============================] - 2s 118ms/step - loss: 0.0568 - accuracy: 0.9816 - val_loss: 0.0528 - val_accuracy: 0.9838
# Epoch 24/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0561 - accuracy: 0.9813 - val_loss: 0.0519 - val_accuracy: 0.9843
# Epoch 25/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 0.0504 - val_accuracy: 0.9849
# Epoch 26/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0544 - accuracy: 0.9819 - val_loss: 0.0498 - val_accuracy: 0.9838
# Epoch 27/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0526 - accuracy: 0.9822 - val_loss: 0.0485 - val_accuracy: 0.9850
# Epoch 28/100
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0517 - accuracy: 0.9825 - val_loss: 0.0483 - val_accuracy: 0.9840
# Epoch 29/100
# 20/20 [==============================] - 2s 124ms/step - loss: 0.0520 - accuracy: 0.9822 - val_loss: 0.0471 - val_accuracy: 0.9851
# Epoch 30/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0519 - accuracy: 0.9828 - val_loss: 0.0479 - val_accuracy: 0.9846
# Epoch 31/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0505 - accuracy: 0.9828 - val_loss: 0.0460 - val_accuracy: 0.9859
# Epoch 32/100
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0488 - accuracy: 0.9834 - val_loss: 0.0455 - val_accuracy: 0.9861
# Epoch 33/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0498 - accuracy: 0.9833 - val_loss: 0.0451 - val_accuracy: 0.9865
# Epoch 34/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0499 - accuracy: 0.9832 - val_loss: 0.0446 - val_accuracy: 0.9862
# Epoch 35/100
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.0443 - val_accuracy: 0.9859
# Epoch 36/100
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0480 - accuracy: 0.9839 - val_loss: 0.0441 - val_accuracy: 0.9861
# Epoch 37/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.0433 - val_accuracy: 0.9865
# Epoch 38/100
# 20/20 [==============================] - 2s 118ms/step - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.0429 - val_accuracy: 0.9856
# Epoch 39/100
# 20/20 [==============================] - 2s 125ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.0435 - val_accuracy: 0.9864
# Epoch 40/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0448 - accuracy: 0.9852 - val_loss: 0.0425 - val_accuracy: 0.9860
# Epoch 41/100
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 0.0420 - val_accuracy: 0.9870
# Epoch 42/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0453 - accuracy: 0.9847 - val_loss: 0.0422 - val_accuracy: 0.9863
# Epoch 43/100
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0440 - accuracy: 0.9852 - val_loss: 0.0413 - val_accuracy: 0.9870
# Epoch 44/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0434 - accuracy: 0.9857 - val_loss: 0.0411 - val_accuracy: 0.9870
# Epoch 45/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.0411 - val_accuracy: 0.9877
# Epoch 46/100
# 20/20 [==============================] - 3s 129ms/step - loss: 0.0424 - accuracy: 0.9854 - val_loss: 0.0405 - val_accuracy: 0.9873
# Epoch 47/100
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0415 - accuracy: 0.9861 - val_loss: 0.0407 - val_accuracy: 0.9868
# Epoch 48/100
# 20/20 [==============================] - 3s 126ms/step - loss: 0.0416 - accuracy: 0.9862 - val_loss: 0.0405 - val_accuracy: 0.9870
# Epoch 49/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0433 - accuracy: 0.9856 - val_loss: 0.0419 - val_accuracy: 0.9872
# Epoch 50/100
# 20/20 [==============================] - 2s 102ms/step - loss: 0.0418 - accuracy: 0.9858 - val_loss: 0.0399 - val_accuracy: 0.9872
# Epoch 51/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.0399 - val_accuracy: 0.9869
# Epoch 52/100
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0409 - accuracy: 0.9865 - val_loss: 0.0396 - val_accuracy: 0.9876
# Epoch 53/100
# 20/20 [==============================] - 2s 103ms/step - loss: 0.0410 - accuracy: 0.9864 - val_loss: 0.0393 - val_accuracy: 0.9872
# Epoch 54/100
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0418 - accuracy: 0.9857 - val_loss: 0.0391 - val_accuracy: 0.9876
# Epoch 55/100
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0401 - accuracy: 0.9867 - val_loss: 0.0394 - val_accuracy: 0.9875
# Epoch 56/100
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0402 - accuracy: 0.9868 - val_loss: 0.0391 - val_accuracy: 0.9876
# Epoch 57/100
# 20/20 [==============================] - 2s 100ms/step - loss: 0.0406 - accuracy: 0.9864 - val_loss: 0.0388 - val_accuracy: 0.9881
# Epoch 58/100
# 20/20 [==============================] - 2s 125ms/step - loss: 0.0382 - accuracy: 0.9871 - val_loss: 0.0382 - val_accuracy: 0.9876
# Epoch 59/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0390 - accuracy: 0.9867 - val_loss: 0.0381 - val_accuracy: 0.9877
# Epoch 60/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0385 - accuracy: 0.9873 - val_loss: 0.0383 - val_accuracy: 0.9880
# Epoch 61/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0389 - accuracy: 0.9870 - val_loss: 0.0381 - val_accuracy: 0.9873
# Epoch 62/100
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0399 - accuracy: 0.9867 - val_loss: 0.0384 - val_accuracy: 0.9875
# Epoch 63/100
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0402 - accuracy: 0.9868 - val_loss: 0.0388 - val_accuracy: 0.9877
# Epoch 64/100
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.0374 - val_accuracy: 0.9880
# Epoch 65/100
# 20/20 [==============================] - 2s 124ms/step - loss: 0.0400 - accuracy: 0.9869 - val_loss: 0.0380 - val_accuracy: 0.9872
# Epoch 66/100
# 20/20 [==============================] - 3s 126ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.0372 - val_accuracy: 0.9881
# Epoch 67/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0381 - accuracy: 0.9871 - val_loss: 0.0371 - val_accuracy: 0.9878
# Epoch 68/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.0369 - val_accuracy: 0.9880
# Epoch 69/100
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0376 - accuracy: 0.9873 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 70/100
# 20/20 [==============================] - 2s 125ms/step - loss: 0.0368 - accuracy: 0.9874 - val_loss: 0.0372 - val_accuracy: 0.9876
# Epoch 71/100
# 20/20 [==============================] - 3s 129ms/step - loss: 0.0375 - accuracy: 0.9875 - val_loss: 0.0370 - val_accuracy: 0.9880
# Epoch 72/100
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.0364 - val_accuracy: 0.9885
# Epoch 73/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.0360 - val_accuracy: 0.9888
# Epoch 74/100
# 20/20 [==============================] - 2s 118ms/step - loss: 0.0355 - accuracy: 0.9876 - val_loss: 0.0363 - val_accuracy: 0.9885
# Epoch 75/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0370 - accuracy: 0.9876 - val_loss: 0.0365 - val_accuracy: 0.9885
# Epoch 76/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0354 - accuracy: 0.9882 - val_loss: 0.0359 - val_accuracy: 0.9879
# Epoch 77/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0352 - accuracy: 0.9882 - val_loss: 0.0365 - val_accuracy: 0.9882
# Epoch 78/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0374 - accuracy: 0.9870 - val_loss: 0.0369 - val_accuracy: 0.9874
# Epoch 79/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0358 - accuracy: 0.9880 - val_loss: 0.0370 - val_accuracy: 0.9883
# Epoch 80/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.0367 - val_accuracy: 0.9883
# Epoch 81/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.0356 - val_accuracy: 0.9885
# Epoch 82/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0347 - accuracy: 0.9885 - val_loss: 0.0358 - val_accuracy: 0.9882
# Epoch 83/100
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.0350 - val_accuracy: 0.9883
# Epoch 84/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0338 - accuracy: 0.9885 - val_loss: 0.0351 - val_accuracy: 0.9886
# Epoch 85/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0344 - accuracy: 0.9889 - val_loss: 0.0349 - val_accuracy: 0.9894
# Epoch 86/100
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0350 - accuracy: 0.9883 - val_loss: 0.0352 - val_accuracy: 0.9894
# Epoch 87/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0335 - accuracy: 0.9885 - val_loss: 0.0348 - val_accuracy: 0.9891
# Epoch 88/100
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0337 - accuracy: 0.9889 - val_loss: 0.0348 - val_accuracy: 0.9890
# Epoch 89/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.0355 - val_accuracy: 0.9892
# Epoch 90/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0338 - accuracy: 0.9889 - val_loss: 0.0343 - val_accuracy: 0.9894
# Epoch 91/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0341 - val_accuracy: 0.9894
# Epoch 92/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0323 - accuracy: 0.9894 - val_loss: 0.0339 - val_accuracy: 0.9894
# Epoch 93/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.0344 - val_accuracy: 0.9889
# Epoch 94/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.0338 - val_accuracy: 0.9892
# Epoch 95/100
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 0.0343 - val_accuracy: 0.9890
# Epoch 96/100
# 20/20 [==============================] - 2s 126ms/step - loss: 0.0338 - accuracy: 0.9884 - val_loss: 0.0343 - val_accuracy: 0.9894
# Epoch 97/100
# 20/20 [==============================] - 3s 130ms/step - loss: 0.0330 - accuracy: 0.9890 - val_loss: 0.0345 - val_accuracy: 0.9888
# Epoch 98/100
# 20/20 [==============================] - 3s 126ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.0343 - val_accuracy: 0.9892
# Epoch 99/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 0.0339 - val_accuracy: 0.9893
# Epoch 100/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0334 - accuracy: 0.9885 - val_loss: 0.0335 - val_accuracy: 0.9892

# %%
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')  # 对于回归任务

# predicting target attribute on testing dataset
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 929/929 [==============================] - 2s 3ms/step - loss: 0.0353 - accuracy: 0.9883
# Test results - Loss: 0.035331979393959045 - Accuracy: 98.82844090461731%

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
